# %% [markdown]
# # Public PDK component inventory
#
# This small notebook verifies the installed public PDK identity and its exported cell registry. The saved output below is rendered directly into the static Quarto site.

# %%
import orpen_sc_pdk

print("Version:", orpen_sc_pdk.__version__)
print("PDK:", orpen_sc_pdk.get_pdk().name)
print("Public cells:", len(orpen_sc_pdk.cells.__all__))
# Out:
# Version: 0.1.0
# PDK: orpen_sc_pdk
# Public cells: 22
